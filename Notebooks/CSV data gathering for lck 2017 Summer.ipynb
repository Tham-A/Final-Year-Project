# %%
import pandas as pd
import numpy as np
import itertools

df = pd.read_csv('LeagueofLegends.csv', converters={'golddiff': pd.eval, 'goldblueTop' : pd.eval, 'goldredTop' : pd.eval})

SKTSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'SKT') | (df['redTeamTag'] == 'SKT'))]
SKTSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'SKT')]
SKTSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'SKT')]

sktarr = np.array(SKTSu17All['golddiff'], object)
sktarr1 = np.array(SKTSu17B['golddiff'], object)
sktarr2 = np.array(SKTSu17R['golddiff'], object)
sktarr3 = np.array(SKTSu17All['goldblueTop'], object)
sktarr4 = np.array(SKTSu17All['goldredTop'], object)
sktarr5 = np.concatenate((sktarr3, sktarr4), axis=0)

# %%
sktsu17all = np.array(list(itertools.zip_longest(*sktarr,fillvalue=np.nan)))
sktsu17b = np.array(list(itertools.zip_longest(*sktarr1,fillvalue=np.nan)))
sktsu17r = np.array(list(itertools.zip_longest(*sktarr2,fillvalue=np.nan)))
sktsu17alltop = np.array(list(itertools.zip_longest(*sktarr5,fillvalue=np.nan)))
sktsu17btop = np.array(list(itertools.zip_longest(*sktarr3,fillvalue=np.nan)))
sktsu17rtop = np.array(list(itertools.zip_longest(*sktarr4,fillvalue=np.nan)))
# You can use numpy.isnan to create a boolean array, and then count the Trues with sum for each row (axis=1)
sktsu17count = list((~np.isnan(sktsu17all)).sum(1))

# %%
JAGSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'JAG') | (df['redTeamTag'] == 'JAG'))]
JAGSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'JAG')]
JAGSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'JAG')]

jagarr = np.array(JAGSu17All['golddiff'], object)
jagarr1 = np.array(JAGSu17B['golddiff'], object)
jagarr2 = np.array(JAGSu17R['golddiff'], object)
jagarr3 = np.array(JAGSu17All['goldblueTop'], object)
jagarr4 = np.array(JAGSu17All['goldredTop'], object)
jagarr5 = np.concatenate((jagarr3, jagarr4), axis=0)

jagsu17all = np.array(list(itertools.zip_longest(*jagarr,fillvalue=np.nan)))
jagsu17b = np.array(list(itertools.zip_longest(*jagarr1,fillvalue=np.nan)))
jagsu17r = np.array(list(itertools.zip_longest(*jagarr2,fillvalue=np.nan)))
jagsu17alltop = np.array(list(itertools.zip_longest(*jagarr5,fillvalue=np.nan)))
jagsu17btop = np.array(list(itertools.zip_longest(*jagarr3,fillvalue=np.nan)))
jagsu17rtop = np.array(list(itertools.zip_longest(*jagarr4,fillvalue=np.nan)))
jagsu17count = list((~np.isnan(jagsu17all)).sum(1))

# %%
MVPSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'MVP') | (df['redTeamTag'] == 'MVP'))]
MVPSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'MVP')]
MVPSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'MVP')]

mvparr = np.array(MVPSu17All['golddiff'], object)
mvparr1 = np.array(MVPSu17B['golddiff'], object)
mvparr2 = np.array(MVPSu17R['golddiff'], object)
mvparr3 = np.array(MVPSu17All['goldblueTop'], object)
mvparr4 = np.array(MVPSu17All['goldredTop'], object)
mvparr5 = np.concatenate((mvparr3, mvparr4), axis=0)

mvpsu17all = np.array(list(itertools.zip_longest(*mvparr,fillvalue=np.nan)))
mvpsu17b = np.array(list(itertools.zip_longest(*mvparr1,fillvalue=np.nan)))
mvpsu17r = np.array(list(itertools.zip_longest(*mvparr2,fillvalue=np.nan)))
mvpsu17alltop = np.array(list(itertools.zip_longest(*mvparr5,fillvalue=np.nan)))
mvpsu17btop = np.array(list(itertools.zip_longest(*mvparr3,fillvalue=np.nan)))
mvpsu17rtop = np.array(list(itertools.zip_longest(*mvparr4,fillvalue=np.nan)))
mvpsu17count = list((~np.isnan(mvpsu17all)).sum(1))

# %%
LZSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'LZ') | (df['redTeamTag'] == 'LZ'))]
LZSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'LZ')]
LZSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'LZ')]

lzarr = np.array(LZSu17All['golddiff'], object)
lzarr1 = np.array(LZSu17B['golddiff'], object)
lzarr2 = np.array(LZSu17R['golddiff'], object)
lzarr3 = np.array(LZSu17All['goldblueTop'], object)
lzarr4 = np.array(LZSu17All['goldredTop'], object)
lzarr5 = np.concatenate((lzarr3, lzarr4), axis=0)

lzsu17all = np.array(list(itertools.zip_longest(*lzarr,fillvalue=np.nan)))
lzsu17b = np.array(list(itertools.zip_longest(*lzarr1,fillvalue=np.nan)))
lzsu17r = np.array(list(itertools.zip_longest(*lzarr2,fillvalue=np.nan)))
lzsu17alltop = np.array(list(itertools.zip_longest(*lzarr5,fillvalue=np.nan)))
lzsu17btop = np.array(list(itertools.zip_longest(*lzarr3,fillvalue=np.nan)))
lzsu17rtop = np.array(list(itertools.zip_longest(*lzarr4,fillvalue=np.nan)))
lzsu17count = list((~np.isnan(lzsu17all)).sum(1))

# %%
KTSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'kt') | (df['redTeamTag'] == 'kt'))]
KTSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'kt')]
KTSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'kt')]

ktarr = np.array(KTSu17All['golddiff'], object)
ktarr1 = np.array(KTSu17B['golddiff'], object)
ktarr2 = np.array(KTSu17R['golddiff'], object)
ktarr3 = np.array(KTSu17All['goldblueTop'], object)
ktarr4 = np.array(KTSu17All['goldredTop'], object)
ktarr5 = np.concatenate((ktarr3, ktarr4), axis=0)

ktsu17all = np.array(list(itertools.zip_longest(*ktarr,fillvalue=np.nan)))
ktsu17b = np.array(list(itertools.zip_longest(*ktarr1,fillvalue=np.nan)))
ktsu17r = np.array(list(itertools.zip_longest(*ktarr2,fillvalue=np.nan)))
ktsu17alltop = np.array(list(itertools.zip_longest(*ktarr5,fillvalue=np.nan)))
ktsu17btop = np.array(list(itertools.zip_longest(*ktarr3,fillvalue=np.nan)))
ktsu17rtop = np.array(list(itertools.zip_longest(*ktarr4,fillvalue=np.nan)))
ktsu17count = list((~np.isnan(ktsu17all)).sum(1))

# %%
EEWSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'EEW') | (df['redTeamTag'] == 'EEW'))]
EEWSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'EEW')]
EEWSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'EEW')]

eewarr = np.array(EEWSu17All['golddiff'], object)
eewarr1 = np.array(EEWSu17B['golddiff'], object)
eewarr2 = np.array(EEWSu17R['golddiff'], object)
eewarr3 = np.array(EEWSu17All['goldblueTop'], object)
eewarr4 = np.array(EEWSu17All['goldredTop'], object)
eewarr5 = np.concatenate((eewarr3, eewarr4), axis=0)

eewsu17all = np.array(list(itertools.zip_longest(*eewarr,fillvalue=np.nan)))
eewsu17b = np.array(list(itertools.zip_longest(*eewarr1,fillvalue=np.nan)))
eewsu17r = np.array(list(itertools.zip_longest(*eewarr2,fillvalue=np.nan)))
eewsu17alltop = np.array(list(itertools.zip_longest(*eewarr5,fillvalue=np.nan)))
eewsu17btop = np.array(list(itertools.zip_longest(*eewarr3,fillvalue=np.nan)))
eewsu17rtop = np.array(list(itertools.zip_longest(*eewarr4,fillvalue=np.nan)))
eewsu17count = list((~np.isnan(eewsu17all)).sum(1))

# %%
AFSSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'AFs') | (df['redTeamTag'] == 'AFs'))]
AFSSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'AFs')]
AFSSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'AFs')]

afsarr = np.array(AFSSu17All['golddiff'], object)
afsarr1 = np.array(AFSSu17B['golddiff'], object)
afsarr2 = np.array(AFSSu17R['golddiff'], object)
afsarr3 = np.array(AFSSu17All['goldblueTop'], object)
afsarr4 = np.array(AFSSu17All['goldredTop'], object)
afsarr5 = np.concatenate((afsarr3, afsarr4), axis=0)

afssu17all = np.array(list(itertools.zip_longest(*afsarr,fillvalue=np.nan)))
afssu17b = np.array(list(itertools.zip_longest(*afsarr1,fillvalue=np.nan)))
afssu17r = np.array(list(itertools.zip_longest(*afsarr2,fillvalue=np.nan)))
afssu17alltop = np.array(list(itertools.zip_longest(*afsarr5,fillvalue=np.nan)))
afssu17btop = np.array(list(itertools.zip_longest(*afsarr3,fillvalue=np.nan)))
afssu17rtop = np.array(list(itertools.zip_longest(*afsarr4,fillvalue=np.nan)))
afssu17count = list((~np.isnan(afssu17all)).sum(1))

# %%
SSGSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'SSG') | (df['redTeamTag'] == 'SSG'))]
SSGSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'SSG')]
SSGSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'SSG')]

ssgarr = np.array(SSGSu17All['golddiff'], object)
ssgarr1 = np.array(SSGSu17B['golddiff'], object)
ssgarr2 = np.array(SSGSu17R['golddiff'], object)
ssgarr3 = np.array(SSGSu17All['goldblueTop'], object)
ssgarr4 = np.array(SSGSu17All['goldredTop'], object)
ssgarr5 = np.concatenate((ssgarr3, ssgarr4), axis=0)

ssgsu17all = np.array(list(itertools.zip_longest(*ssgarr,fillvalue=np.nan)))
ssgsu17b = np.array(list(itertools.zip_longest(*ssgarr1,fillvalue=np.nan)))
ssgsu17r = np.array(list(itertools.zip_longest(*ssgarr2,fillvalue=np.nan)))
ssgsu17alltop = np.array(list(itertools.zip_longest(*ssgarr5,fillvalue=np.nan)))
ssgsu17btop = np.array(list(itertools.zip_longest(*ssgarr3,fillvalue=np.nan)))
ssgsu17rtop = np.array(list(itertools.zip_longest(*ssgarr4,fillvalue=np.nan)))
ssgsu17count = list((~np.isnan(ssgsu17all)).sum(1))

# %%
BBQSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'bbq') | (df['redTeamTag'] == 'bbq'))]
BBQSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'bbq')]
BBQSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'bbq')]

bbqarr = np.array(BBQSu17All['golddiff'], object)
bbqarr1 = np.array(BBQSu17B['golddiff'], object)
bbqarr2 = np.array(BBQSu17R['golddiff'], object)
bbqarr3 = np.array(BBQSu17All['goldblueTop'], object)
bbqarr4 = np.array(BBQSu17All['goldredTop'], object)
bbqarr5 = np.concatenate((bbqarr3, bbqarr4), axis=0)

bbqsu17all = np.array(list(itertools.zip_longest(*bbqarr,fillvalue=np.nan)))
bbqsu17b = np.array(list(itertools.zip_longest(*bbqarr1,fillvalue=np.nan)))
bbqsu17r = np.array(list(itertools.zip_longest(*bbqarr2,fillvalue=np.nan)))
bbqsu17alltop = np.array(list(itertools.zip_longest(*bbqarr5,fillvalue=np.nan)))
bbqsu17btop = np.array(list(itertools.zip_longest(*bbqarr3,fillvalue=np.nan)))
bbqsu17rtop = np.array(list(itertools.zip_longest(*bbqarr4,fillvalue=np.nan)))
bbqsu17count = list((~np.isnan(bbqsu17all)).sum(1))

# %%
ROXSu17All = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & ((df['blueTeamTag'] == 'ROX') | (df['redTeamTag'] == 'ROX'))]
ROXSu17B = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['blueTeamTag'] == 'ROX')]
ROXSu17R = df[(df['League'] == 'LCK') & (df['Year'] == 2017) & (df['Season'] == 'Summer') & (df['redTeamTag'] == 'ROX')]

roxarr = np.array(ROXSu17All['golddiff'], object)
roxarr1 = np.array(ROXSu17B['golddiff'], object)
roxarr2 = np.array(ROXSu17R['golddiff'], object)
roxarr3 = np.array(ROXSu17All['goldblueTop'], object)
roxarr4 = np.array(ROXSu17All['goldredTop'], object)
roxarr5 = np.concatenate((roxarr3, roxarr4), axis=0)

roxsu17all = np.array(list(itertools.zip_longest(*roxarr,fillvalue=np.nan)))
roxsu17b = np.array(list(itertools.zip_longest(*roxarr1,fillvalue=np.nan)))
roxsu17r = np.array(list(itertools.zip_longest(*roxarr2,fillvalue=np.nan)))
roxsu17alltop = np.array(list(itertools.zip_longest(*roxarr5,fillvalue=np.nan)))
roxsu17btop = np.array(list(itertools.zip_longest(*roxarr3,fillvalue=np.nan)))
roxsu17rtop = np.array(list(itertools.zip_longest(*roxarr4,fillvalue=np.nan)))
roxsu17count = list((~np.isnan(roxsu17all)).sum(1))

# %%
#np.set_printoptions(precision=2, suppress=True)

# %%
sktsu17all = np.nanmean(sktsu17all, axis=1)
sktsu17all = list(sktsu17all)
sktsu17all = [ round(elem, 2) for elem in sktsu17all]
sktsu17b = np.nanmean(sktsu17b, axis=1)
sktsu17b = list(sktsu17b)
sktsu17b = [ round(elem, 2) for elem in sktsu17b]
sktsu17r = np.nanmean(sktsu17r, axis=1)
sktsu17r = list(sktsu17r)
sktsu17r = [ round(elem, 2) for elem in sktsu17r]

sktsu17alltop = np.nanmean(sktsu17alltop, axis=1)
sktsu17alltop = list(sktsu17alltop)
sktsu17alltop = [ round(elem, 2) for elem in sktsu17alltop]
sktsu17btop = np.nanmean(sktsu17btop, axis=1)
sktsu17btop = list(sktsu17btop)
sktsu17btop = [ round(elem, 2) for elem in sktsu17btop]
sktsu17rtop = np.nanmean(sktsu17rtop, axis=1)
sktsu17rtop = list(sktsu17rtop)
sktsu17rtop = [ round(elem, 2) for elem in sktsu17rtop]

mvpsu17all = np.nanmean(mvpsu17all, axis=1)
mvpsu17all = list(mvpsu17all)
mvpsu17all = [ round(elem, 2) for elem in mvpsu17all]
mvpsu17b = np.nanmean(mvpsu17b, axis=1)
mvpsu17b = list(mvpsu17b)
mvpsu17b = [ round(elem, 2) for elem in mvpsu17b]
mvpsu17r = np.nanmean(mvpsu17r, axis=1)
mvpsu17r = list(mvpsu17r)
mvpsu17r = [ round(elem, 2) for elem in mvpsu17r]

mvpsu17alltop = np.nanmean(mvpsu17alltop, axis=1)
mvpsu17alltop = list(mvpsu17alltop)
mvpsu17alltop = [ round(elem, 2) for elem in mvpsu17alltop]
mvpsu17btop = np.nanmean(mvpsu17btop, axis=1)
mvpsu17btop = list(mvpsu17btop)
mvpsu17btop = [ round(elem, 2) for elem in mvpsu17btop]
mvpsu17rtop = np.nanmean(mvpsu17rtop, axis=1)
mvpsu17rtop = list(mvpsu17rtop)
mvpsu17rtop = [ round(elem, 2) for elem in mvpsu17rtop]

jagsu17all = np.nanmean(jagsu17all, axis=1)
jagsu17all = list(jagsu17all)
jagsu17all = [ round(elem, 2) for elem in jagsu17all]
jagsu17b = np.nanmean(jagsu17b, axis=1)
jagsu17b = list(jagsu17b)
jagsu17b = [ round(elem, 2) for elem in jagsu17b]
jagsu17r = np.nanmean(jagsu17r, axis=1)
jagsu17r = list(jagsu17r)
jagsu17r = [ round(elem, 2) for elem in jagsu17r]

jagsu17alltop = np.nanmean(jagsu17alltop, axis=1)
jagsu17alltop = list(jagsu17alltop)
jagsu17alltop = [ round(elem, 2) for elem in jagsu17alltop]
jagsu17btop = np.nanmean(jagsu17btop, axis=1)
jagsu17btop = list(jagsu17btop)
jagsu17btop = [ round(elem, 2) for elem in jagsu17btop]
jagsu17rtop = np.nanmean(jagsu17rtop, axis=1)
jagsu17rtop = list(jagsu17rtop)
jagsu17rtop = [ round(elem, 2) for elem in jagsu17rtop]

lzsu17all = np.nanmean(lzsu17all, axis=1)
lzsu17all = list(lzsu17all)
lzsu17all = [ round(elem, 2) for elem in lzsu17all]
lzsu17b = np.nanmean(lzsu17b, axis=1)
lzsu17b = list(lzsu17b)
lzsu17b = [ round(elem, 2) for elem in lzsu17b]
lzsu17r = np.nanmean(lzsu17r, axis=1)
lzsu17r = list(lzsu17r)
lzsu17r = [ round(elem, 2) for elem in lzsu17r]

lzsu17alltop = np.nanmean(lzsu17alltop, axis=1)
lzsu17alltop = list(lzsu17alltop)
lzsu17alltop = [ round(elem, 2) for elem in lzsu17alltop]
lzsu17btop = np.nanmean(lzsu17btop, axis=1)
lzsu17btop = list(lzsu17btop)
lzsu17btop = [ round(elem, 2) for elem in lzsu17btop]
lzsu17rtop = np.nanmean(lzsu17rtop, axis=1)
lzsu17rtop = list(lzsu17rtop)
lzsu17rtop = [ round(elem, 2) for elem in lzsu17rtop]

ktsu17all = np.nanmean(ktsu17all, axis=1)
ktsu17all = list(ktsu17all)
ktsu17all = [ round(elem, 2) for elem in ktsu17all]
ktsu17b = np.nanmean(ktsu17b, axis=1)
ktsu17b = list(ktsu17b)
ktsu17b = [ round(elem, 2) for elem in ktsu17b]
ktsu17r = np.nanmean(ktsu17r, axis=1)
ktsu17r = list(ktsu17r)
ktsu17r = [ round(elem, 2) for elem in ktsu17r]

ktsu17alltop = np.nanmean(ktsu17alltop, axis=1)
ktsu17alltop = list(ktsu17alltop)
ktsu17alltop = [ round(elem, 2) for elem in ktsu17alltop]
ktsu17btop = np.nanmean(ktsu17btop, axis=1)
ktsu17btop = list(ktsu17btop)
ktsu17btop = [ round(elem, 2) for elem in ktsu17btop]
ktsu17rtop = np.nanmean(ktsu17rtop, axis=1)
ktsu17rtop = list(ktsu17rtop)
ktsu17rtop = [ round(elem, 2) for elem in ktsu17rtop]

eewsu17all = np.nanmean(eewsu17all, axis=1)
eewsu17all = list(eewsu17all)
eewsu17all = [ round(elem, 2) for elem in eewsu17all]
eewsu17b = np.nanmean(eewsu17b, axis=1)
eewsu17b = list(eewsu17b)
eewsu17b = [ round(elem, 2) for elem in eewsu17b]
eewsu17r = np.nanmean(eewsu17r, axis=1)
eewsu17r = list(eewsu17r)
eewsu17r = [ round(elem, 2) for elem in eewsu17r]

eewsu17alltop = np.nanmean(eewsu17alltop, axis=1)
eewsu17alltop = list(eewsu17alltop)
eewsu17alltop = [ round(elem, 2) for elem in eewsu17alltop]
eewsu17btop = np.nanmean(eewsu17btop, axis=1)
eewsu17btop = list(eewsu17btop)
eewsu17btop = [ round(elem, 2) for elem in eewsu17btop]
eewsu17rtop = np.nanmean(eewsu17rtop, axis=1)
eewsu17rtop = list(eewsu17rtop)
eewsu17rtop = [ round(elem, 2) for elem in eewsu17rtop]

afssu17all = np.nanmean(afssu17all, axis=1)
afssu17all = list(afssu17all)
afssu17all = [ round(elem, 2) for elem in afssu17all]
afssu17b = np.nanmean(afssu17b, axis=1)
afssu17b = list(afssu17b)
afssu17b = [ round(elem, 2) for elem in afssu17b]
afssu17r = np.nanmean(afssu17r, axis=1)
afssu17r = list(afssu17r)
afssu17r = [ round(elem, 2) for elem in afssu17r]

afssu17alltop = np.nanmean(afssu17alltop, axis=1)
afssu17alltop = list(afssu17alltop)
afssu17alltop = [ round(elem, 2) for elem in afssu17alltop]
afssu17btop = np.nanmean(afssu17btop, axis=1)
afssu17btop = list(afssu17btop)
afssu17btop = [ round(elem, 2) for elem in afssu17btop]
afssu17rtop = np.nanmean(afssu17rtop, axis=1)
afssu17rtop = list(afssu17rtop)
afssu17rtop = [ round(elem, 2) for elem in afssu17rtop]

ssgsu17all = np.nanmean(ssgsu17all, axis=1)
ssgsu17all = list(ssgsu17all)
ssgsu17all = [ round(elem, 2) for elem in ssgsu17all]
ssgsu17b = np.nanmean(ssgsu17b, axis=1)
ssgsu17b = list(ssgsu17b)
ssgsu17b = [ round(elem, 2) for elem in ssgsu17b]
ssgsu17r = np.nanmean(ssgsu17r, axis=1)
ssgsu17r = list(ssgsu17r)
ssgsu17r = [ round(elem, 2) for elem in ssgsu17r]

ssgsu17alltop = np.nanmean(ssgsu17alltop, axis=1)
ssgsu17alltop = list(ssgsu17alltop)
ssgsu17alltop = [ round(elem, 2) for elem in ssgsu17alltop]
ssgsu17btop = np.nanmean(ssgsu17btop, axis=1)
ssgsu17btop = list(ssgsu17btop)
ssgsu17btop = [ round(elem, 2) for elem in ssgsu17btop]
ssgsu17rtop = np.nanmean(ssgsu17rtop, axis=1)
ssgsu17rtop = list(ssgsu17rtop)
ssgsu17rtop = [ round(elem, 2) for elem in ssgsu17rtop]

bbqsu17all = np.nanmean(bbqsu17all, axis=1)
bbqsu17all = list(bbqsu17all)
bbqsu17all = [ round(elem, 2) for elem in bbqsu17all]
bbqsu17b = np.nanmean(bbqsu17b, axis=1)
bbqsu17b = list(bbqsu17b)
bbqsu17b = [ round(elem, 2) for elem in bbqsu17b]
bbqsu17r = np.nanmean(bbqsu17r, axis=1)
bbqsu17r = list(bbqsu17r)
bbqsu17r = [ round(elem, 2) for elem in bbqsu17r]

bbqsu17alltop = np.nanmean(bbqsu17alltop, axis=1)
bbqsu17alltop = list(bbqsu17alltop)
bbqsu17alltop = [ round(elem, 2) for elem in bbqsu17alltop]
bbqsu17btop = np.nanmean(bbqsu17btop, axis=1)
bbqsu17btop = list(bbqsu17btop)
bbqsu17btop = [ round(elem, 2) for elem in bbqsu17btop]
bbqsu17rtop = np.nanmean(bbqsu17rtop, axis=1)
bbqsu17rtop = list(bbqsu17rtop)
bbqsu17rtop = [ round(elem, 2) for elem in bbqsu17rtop]

roxsu17all = np.nanmean(roxsu17all, axis=1)
roxsu17all = list(roxsu17all)
roxsu17all = [ round(elem, 2) for elem in roxsu17all]
roxsu17b = np.nanmean(roxsu17b, axis=1)
roxsu17b = list(roxsu17b)
roxsu17b = [ round(elem, 2) for elem in roxsu17b]
roxsu17r = np.nanmean(roxsu17r, axis=1)
roxsu17r = list(roxsu17r)
roxsu17r = [ round(elem, 2) for elem in roxsu17r]

roxsu17alltop = np.nanmean(roxsu17alltop, axis=1)
roxsu17alltop = list(roxsu17alltop)
roxsu17alltop = [ round(elem, 2) for elem in roxsu17alltop]
roxsu17btop = np.nanmean(roxsu17btop, axis=1)
roxsu17btop = list(roxsu17btop)
roxsu17btop = [ round(elem, 2) for elem in roxsu17btop]
roxsu17rtop = np.nanmean(roxsu17rtop, axis=1)
roxsu17rtop = list(roxsu17rtop)
roxsu17rtop = [ round(elem, 2) for elem in roxsu17rtop]

# %%
import csv

row_list = [["Team", "Golddiff", "Side", "Count", "TopGold"],
           ["SKT", sktsu17all, "Both", sktsu17count, sktsu17alltop],
           ["SKT", sktsu17b, "Blue", sktsu17count, sktsu17btop],
           ["SKT", sktsu17r, "Red", sktsu17count, sktsu17rtop],
           ["MVP", mvpsu17all, "Both", mvpsu17count, mvpsu17alltop],
           ["MVP", mvpsu17b, "Blue", mvpsu17count, mvpsu17btop],
           ["MVP", mvpsu17r, "Red", mvpsu17count, mvpsu17rtop],
           ["JAG", jagsu17all, "Both", jagsu17count, jagsu17alltop],
           ["JAG", jagsu17b, "Blue", jagsu17count, jagsu17btop],
           ["JAG", jagsu17r, "Red", jagsu17count, jagsu17rtop],
           ["LZ", lzsu17all, "Both", lzsu17count, lzsu17alltop],
           ["LZ", lzsu17b, "Blue", lzsu17count, lzsu17btop],
           ["LZ", lzsu17r, "Red", lzsu17count, lzsu17rtop],
           ["KT", ktsu17all, "Both", ktsu17count, ktsu17alltop],
           ["KT", ktsu17b, "Blue", ktsu17count, ktsu17btop],
           ["KT", ktsu17r, "Red", ktsu17count, ktsu17rtop],
           ["EEW", eewsu17all, "Both", eewsu17count, eewsu17alltop],
           ["EEW", eewsu17b, "Blue", eewsu17count, eewsu17btop],
           ["EEW", eewsu17r, "Red", eewsu17count, eewsu17rtop],
           ["AFS", afssu17all, "Both", afssu17count, afssu17alltop],
           ["AFS", afssu17b, "Blue", afssu17count, afssu17btop],
           ["AFS", afssu17r, "Red", afssu17count, afssu17rtop],
           ["SSG", ssgsu17all, "Both", ssgsu17count, ssgsu17alltop],
           ["SSG", ssgsu17b, "Blue", ssgsu17count, ssgsu17btop],
           ["SSG", ssgsu17r, "Red", ssgsu17count, ssgsu17rtop],
           ["BBQ", bbqsu17all, "Both", bbqsu17count, bbqsu17alltop],
           ["BBQ", bbqsu17b, "Blue", bbqsu17count, bbqsu17btop],
           ["BBQ", bbqsu17r, "Red", bbqsu17count, bbqsu17rtop],
           ["ROX", roxsu17all, "Both", roxsu17count, roxsu17alltop],
           ["ROX", roxsu17b, "Blue", roxsu17count, roxsu17btop],
           ["ROX", roxsu17r, "Red", roxsu17count, roxsu17rtop],]

with open('LCKSummer2017.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)
